# %% [markdown]
# # Instructions
#
# ```
# mkdir -p ~/.aws
# cp ~/.nsdf/vault/aws/* ~/.aws/config
# chmod 700 -R ~/.aws/config
#
# # test if it works
# aws s3 --no-verify-ssl --profile sealstorage ls s3://utah/
# ```

# %%
import os,sys

# this is only needed scrgiorgio my machine
sys.path.append(r"C:\projects\OpenVisus\build\RelWithDebInfo")

import OpenVisus as ov
# Out:
# Starting OpenVisus /home/gtarcea/.local/lib/python3.10/site-packages/OpenVisus/__init__.py 3.10.6 (main, Nov  2 2022, 18:53:38) [GCC 11.3.0] sys.version_info(major=3, minor=10, micro=6, releaselevel='final', serial=0) ...

# %%
# this is the remote you are getting from the datasets.yaml file
remote="s3://utah/openvisus-commons/1mb/tmp/conferece-data/image-9-1431714122885/visus.idx"

# %%
profile, key="sealstorage",remote[len("s3://"):]
url=f"https://maritime.sealstorage.io/api/v0/s3/{key}?profile={profile}"
print("Loading dataset from",url)
db=ov.LoadDataset(url)
# Out:
# Loading dataset from https://maritime.sealstorage.io/api/v0/s3/utah/openvisus-commons/1mb/dsmedica/capilla/capilla00005/visus.idx?profile=sealstorage

# %%
# !!!!!!!!!!!!!!!! TODO: set a max resolution for BIG DATASET !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!! do this only for SMALL DATASET ()          !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
data=db.read()
# Out:
# 154124492 Kernel:273 219896:140439246880768 setting VISUS_HOME from home directory /home/gtarcea/visus
# 154124492 Kernel:293 219896:140439246880768 setting VISUS_CACHE from VISUS_HOME /home/gtarcea/visus/cache
# 154124492 Kernel:383 219896:140439246880768 VISUS_VERSION
# 154124492 Kernel:384 219896:140439246880768 VISUS_GIT_REVISION 41c031d
# 154124492 Kernel:385 219896:140439246880768 VISUS_HOME /home/gtarcea/visus
# 154124492 Kernel:386 219896:140439246880768 VISUS_CACHE /home/gtarcea/visus/cache
# 154124492 Kernel:387 219896:140439246880768 VISUS_BINARY_DIR /home/gtarcea/.local/lib/python3.10/site-packages/OpenVisus/bin
# 154124492 Kernel:388 219896:140439246880768 GetCurrentWorkingDirectory() /home/gtarcea/Downloads/nb
# 154124492 VisusDbPy:77 219896:140439246880768 Registering PyMultipleDataset
# ...

# %%
from matplotlib import pyplot as plt
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
plt.imsave('imsave.png', data)
